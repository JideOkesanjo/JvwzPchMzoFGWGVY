# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

# %%
sheet_id = '117X6i53dKiO7w6kuA1g1TpdTlv1173h_dPlJt5cNNMU'
url = 'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_id}'.format(sheet_id=sheet_id)
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location  connection  fit
# 0                       Houston, Texas        85.0  NaN
# 1                               Kanada         NaN  NaN
# 2  Raleigh-Durham, North Carolina Area        44.0  NaN
# 3                        Denton, Texas         NaN  NaN
# 4                       İzmir, Türkiye         NaN  NaN

# %%
df.loc[df['location'] == 'Kanada', 'location'] = 'Canada'

# %%
import gensim
from gensim.models import Word2Vec
import string

# %%
def remove_digits_punc(df):
  df['job_title'] = df['job_title'].str.replace('\d+', '')
  df['job_title'] = df['job_title'].str.replace('[^\w\s]', '')

  return df


df = remove_digits_punc(df)

df.head()
# Out:
# <ipython-input-6-695e426ade9c>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['job_title'] = df['job_title'].str.replace('\d+', '')
# <ipython-input-6-695e426ade9c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['job_title'] = df['job_title'].str.replace('[^\w\s]', '')
#    id                                          job_title  \
# 0   1   CT Bauer College of Business Graduate Magna C...
# 1   2  Native English Teacher at EPIK English Program...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location  connection  fit
# 0                       Houston, Texas        85.0  NaN
# 1                               Canada         NaN  NaN
# 2  Raleigh-Durham, North Carolina Area        44.0  NaN
# 3                        Denton, Texas         NaN  NaN
# 4                       İzmir, Türkiye         NaN  NaN

# %%
# Tokenization
tokenized_titles = [gensim.utils.simple_preprocess(title) for title in df['job_title']]

# Training the Word2Vec model
model = Word2Vec(sentences=tokenized_titles, vector_size=100, window=5, min_count=1, workers=4, sg=0)

# Calculate similarity with "aspiring human resources"
keyword_vector = (model.wv['aspiring'] + model.wv['human'] + model.wv['resources']) / 3

similarities = []
title_vectors = []
for title_tokens in tokenized_titles:
    title_vector = sum([model.wv[token] for token in title_tokens if token in model.wv]) / len(title_tokens)
    sim = cosine_similarity([title_vector], [keyword_vector])[0][0]
    title_vectors.append(title_vector)
    similarities.append(sim)

# Attach similarities to the dataframe and sort
df['fit'] = similarities
df_sorted = df.sort_values(by='fit', ascending=False)

# %%
df = df.sort_values(by='fit', ascending=False)

# %%
df.head(20)
# Out:
#      id                                          job_title  \
# 5     6                Aspiring Human Resources Specialist
# 35   36                Aspiring Human Resources Specialist
# 59   60                Aspiring Human Resources Specialist
# 23   24                Aspiring Human Resources Specialist
# 48   49                Aspiring Human Resources Specialist
# 16   17              Aspiring Human Resources Professional
# 2     3              Aspiring Human Resources Professional
# 32   33              Aspiring Human Resources Professional
# 20   21              Aspiring Human Resources Professional
# 96   97              Aspiring Human Resources Professional
# 57   58              Aspiring Human Resources Professional
# 45   46              Aspiring Human Resources Professional
# 72   73  Aspiring Human Resources Manager seeking inter...
# 99  100  Aspiring Human Resources Manager  Graduating M...
# 73   74                       Human Resources Professional
# 78   79  Liberal Arts Major Aspiring Human Resources An...
# 87   88                   Human Resources Management Major
# 29   30              Seeking Human Resources Opportunities
# 27   28              Seeking Human Resources Opportunities
# 98   99                   Seeking Human Resources Position
#
#                                location  connection       fit
# 5            Greater New York City Area         1.0  0.872899
# 35           Greater New York City Area         1.0  0.872899
# 59           Greater New York City Area         1.0  0.872899
# 23           Greater New York City Area         1.0  0.872899
# 48           Greater New York City Area         1.0  0.872899
# 16  Raleigh-Durham, North Carolina Area        44.0  0.865508
# 2   Raleigh-Durham, North Carolina Area        44.0  0.865508
# 32  Raleigh-Durham, North Carolina Area        44.0  0.865508
# 20  Raleigh-Durham, North Carolina Area        44.0  0.865508
# 96                 Kokomo, Indiana Area        71.0  0.865508
# 57  Raleigh-Durham, North Carolina Area        44.0  0.865508
# 45  Raleigh-Durham, North Carolina Area        44.0  0.865508
# 72                  Houston, Texas Area         7.0  0.817877
# 99             Cape Girardeau, Missouri       103.0  0.739726
# 73                  Greater Boston Area        16.0  0.712742
# 78          Baton Rouge, Louisiana Area         7.0  0.687180
# 87                 Milpitas, California        18.0  0.673991
# 29                    Chicago, Illinois       390.0  0.663295
# 27                    Chicago, Illinois       390.0  0.663295
# 98               Las Vegas, Nevada Area        48.0  0.658140

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X = title_vectors
y = df['fit']

# %%
rf = RandomForestRegressor()
rf.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
df['predicted_fit'] = rf.predict(X)
df_sorted = df.sort_values(by='predicted_fit', ascending=False)
df_sorted.head(20)
# Out:
#     id                            job_title                    location  \
# 5    6  Aspiring Human Resources Specialist  Greater New York City Area
# 23  24  Aspiring Human Resources Specialist  Greater New York City Area
# 48  49  Aspiring Human Resources Specialist  Greater New York City Area
# 35  36  Aspiring Human Resources Specialist  Greater New York City Area
# 59  60  Aspiring Human Resources Specialist  Greater New York City Area
# ..  ..                                  ...                         ...
# 37  38                 HR Senior Specialist      San Francisco Bay Area
# 60  61                 HR Senior Specialist      San Francisco Bay Area
# 7    8                 HR Senior Specialist      San Francisco Bay Area
# 50  51                 HR Senior Specialist      San Francisco Bay Area
# 25  26                 HR Senior Specialist      San Francisco Bay Area
#
#     connection       fit  predicted_fit
# 5          1.0  0.872899       0.872899
# 23         1.0  0.872899       0.872899
# 48         1.0  0.872899       0.872899
# 35         1.0  0.872899       0.872899
# 59         1.0  0.872899       0.872899
# ..         ...       ...            ...
# 37         NaN -0.068548      -0.068548
# 60         NaN -0.068548      -0.068548
# 7          NaN -0.068548      -0.068548
# 50         NaN -0.068548      -0.068548
# 25         NaN -0.068548      -0.068548
#
# [104 rows x 6 columns]

# %%
df_sorted.loc[df_sorted['predicted_fit'] > 0.5]
# Out:
#       id                                          job_title  \
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 74    75  Nortia Staffing is seeking Human Resources Pay...
# 80    81  Senior Human Resources Business Partner at Hei...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 69    70  Retired Army National Guard Recruiter office m...
# 75    76  Aspiring Human Resources Professional  Passion...
# 64    65  Human Resources Coordinator at InterContinenta...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 55    56  Human Resources Coordinator at InterContinenta...
# 42    43  Human Resources Coordinator at InterContinenta...
# 12    13  Human Resources Coordinator at InterContinenta...
# 70    71      Human Resources Generalist at ScottMadden Inc
# 90    91       Lead Official at Western Illinois University
# 54    55  SVP CHRO Marketing  Communications CSR Officer...
# 40    41                      Student at Chapman University
# 79    80            Junior MES Engineer Information Systems
# 34    35    Advisory Board Member at Celal Bayar University
# 22    23    Advisory Board Member at Celal Bayar University
# 86    87  Bachelor of Science in Biology from Victoria U...
# 4      5    Advisory Board Member at Celal Bayar University
# 91    92  Seeking employment opportunities within Custom...
# 47    48    Advisory Board Member at Celal Bayar University
# 62    63                      Student at Chapman University
# 92    93  Admissions Representative at Community medical...
# 53    54                      Student at Chapman University
# 41    42  SVP CHRO Marketing  Communications CSR Officer...
# 103  104   Director Of Administration at Excellence Logging
# 102  103                     Always set them up for Success
# 10    11                      Student at Chapman University
# 31    32  Native English Teacher at EPIK English Program...
# 15    16  Native English Teacher at EPIK English Program...
# 19    20  Native English Teacher at EPIK English Program...
# 1      2  Native English Teacher at EPIK English Program...
# 94    95              Student at Westfield State University
# 11    12  SVP CHRO Marketing  Communications CSR Officer...
# 44    45  Native English Teacher at EPIK English Program...
# 85    86  Information Systems Specialist and Programmer ...
# 101  102   Business Intelligence and Analytics at Travelers
# 84    85  RRP Brand Portfolio Executive at JTI Japan Tob...
# 82    83          HR Manager at Endemol Shine North America
# 89    90  Undergraduate Research Assistant at Styczynski...
# 63    64  SVP CHRO Marketing  Communications CSR Officer...
# 33    34             People Development Coordinator at Ryan
# 3      4             People Development Coordinator at Ryan
# 95    96  Student at Indiana University Kokomo  Business...
# 21    22             People Development Coordinator at Ryan
# 46    47             People Development Coordinator at Ryan
# 17    18             People Development Coordinator at Ryan
# 58    59             People Development Coordinator at Ryan
# 97    98                                            Student
# 37    38                               HR Senior Specialist
# 60    61                               HR Senior Specialist
# 7      8                               HR Senior Specialist
# 50    51                               HR Senior Specialist
# 25    26                               HR Senior Specialist
#
#                                 location  connection       fit  predicted_fit
# 61             Greater Philadelphia Area         NaN  0.460635       0.460004
# 74                  San Jose, California         NaN  0.458063       0.460004
# 80           Chattanooga, Tennessee Area       455.0  0.460602       0.460004
# 39             Greater Philadelphia Area         NaN  0.460635       0.460004
# 69              Virginia Beach, Virginia        82.0  0.415977       0.453546
# 75                    New York, New York       212.0  0.413029       0.449444
# 64                      Atlanta, Georgia         NaN  0.421053       0.444882
# 52             Greater Philadelphia Area         NaN  0.460635       0.443868
# 55                      Atlanta, Georgia         NaN  0.421053       0.434512
# 42                      Atlanta, Georgia         NaN  0.421053       0.410396
# 12                      Atlanta, Georgia         NaN  0.421053       0.376660
# 70   Raleigh-Durham, North Carolina Area         NaN  0.360385       0.289772
# 90                  Greater Chicago Area        39.0  0.203520       0.197446
# 54                   Houston, Texas Area         NaN  0.091202       0.179881
# 40               Lake Forest, California         2.0  0.123178       0.179843
# 79     Myrtle Beach, South Carolina Area        52.0  0.035497       0.177925
# 34                        İzmir, Türkiye         NaN  0.144282       0.163308
# 22                        İzmir, Türkiye         NaN  0.144282       0.163308
# 86                   Baltimore, Maryland        40.0  0.133659       0.163308
# 4                         İzmir, Türkiye         NaN  0.144282       0.163308
# 91                  Torrance, California        64.0  0.184286       0.163308
# 47                        İzmir, Türkiye         NaN  0.144282       0.163308
# 62               Lake Forest, California         2.0  0.123178       0.159916
# 92                Long Beach, California         9.0  0.054802       0.155967
# 53               Lake Forest, California         2.0  0.123178       0.153568
# 41                   Houston, Texas Area         NaN  0.091202       0.147059
# 103                          Katy, Texas         NaN  0.129774       0.131608
# 102             Greater Los Angeles Area         NaN -0.030182       0.127294
# 10               Lake Forest, California         2.0  0.123178       0.125084
# 31                                Canada         NaN  0.106474       0.108770
# 15                                Canada         NaN  0.106474       0.106886
# 19                                Canada         NaN  0.106474       0.106886
# 1                                 Canada         NaN  0.106474       0.106886
# 94            Bridgewater, Massachusetts        57.0  0.107402       0.106886
# 11                   Houston, Texas Area         NaN  0.091202       0.104932
# 44                                Canada         NaN  0.106474       0.099392
# 85                Gaithersburg, Maryland         4.0  0.092952       0.099392
# 101           Greater New York City Area        49.0  0.098679       0.099392
# 84             Greater Philadelphia Area         NaN  0.096933       0.099392
# 82               Los Angeles, California       268.0  0.032698       0.099263
# 89                  Greater Atlanta Area       155.0  0.082723       0.076089
# 63                   Houston, Texas Area         NaN  0.091202       0.076089
# 33                         Denton, Texas         NaN  0.062810       0.076089
# 3                          Denton, Texas         NaN  0.062810       0.076089
# 95                    Lafayette, Indiana        19.0  0.079288       0.076089
# 21                         Denton, Texas         NaN  0.062810       0.065296
# 46                         Denton, Texas         NaN  0.062810       0.065296
# 17                         Denton, Texas         NaN  0.062810       0.065296
# 58                         Denton, Texas         NaN  0.062810       0.065296
# 97                   Houston, Texas Area         4.0  0.009474       0.060389
# 37                San Francisco Bay Area         NaN -0.068548      -0.068548
# 60                San Francisco Bay Area         NaN -0.068548      -0.068548
# 7                 San Francisco Bay Area         NaN -0.068548      -0.068548
# 50                San Francisco Bay Area         NaN -0.068548      -0.068548
# 25                San Francisco Bay Area         NaN -0.068548      -0.068548
